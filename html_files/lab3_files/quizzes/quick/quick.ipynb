# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8888/notebooks/quick/Untitled.ipynb?kernel_name=python3#Solution-to-Quick-Review" data-toc-modified-id="Solution-to-Quick-Review-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Solution to Quick Review</a></span></li></ul></div>

# %% [markdown]
# Solution to Quick Review
# ========================
#
# ****
#
# ****
#
# 1.  **x + y**
#
#     ![](img1.gif)
#
#     Click on the picture for a three-dimensional look at the solution.
#     [![](in3d.jpg%0A){height="50"}](quick_ques1.html%0A){#tex2html1}
#
# 2.  ![](img2.gif)
#
#     ![](img3.gif)
#
# 3.  **y-x**
#
#     ![](img4.gif)
#
#     Click on the picture for a three-dimensional look of the solution.
#     [![](in3d.jpg){height="50"}](quick_ques3.html%0A){#tex2html2}
#
# 4.  **Ax** *i.e. ![](img5.gif) times ![](img6.gif)*
#
#     ![](img7.gif)
#
#     Note that in this multiplication, the values of the same subscript
#     match, i.e.:
#
#     ![](img8.gif)
#
# 5.  ![](img9.gif) *i.e. ![](img10.gif) times ![](img11.gif)*
#
#     ![](img12.gif)
#
#     As you can see, **A** is "too small" for **y**. There is nothing for
#     ![](img13.gif) to multiply by. Another way to think of this is that
#     the size of **A** and **y** do not match, i.e.
#
#     ![](img14.gif)
#
#     Unlike in question 4, where the subscript **j** in both **A** and
#     **x** have the same values, the subscript **i** that appears in
#     **y** and **A** in this question do not have the same values.
#
# 6.  **AB** *i.e. ![](img15.gif) times ![](img16.gif)*
#
#     ![](img17.gif)
#
#     In this question, a 2 x 3 matrix is multiplied to a 3 x 2 matrix.
#     Consider the subscripts:
#
#     ![](img18.gif)
#
#     Note that:
#
#     -   the inner matrix dimensions (pointed by arrows) agree
#     -   the outer matrix dimensions determine the size of the resulting
#         matrix, i.e. the answer is a 2 x 2 matrix.
#
# 7.  **BA** *i.e. ![](img19.gif) times ![](img20.gif)*
#
#     ![](img21.gif)
#
#     In this question, a 3 x 2 matrix is multiplied to a 2 x 3 matrix.
#     Consider the subscripts:
#
#     ![](img22.gif)
#
#     Note that:
#
#     -   the inner matrix dimensions (pointed by arrows) agree
#     -   the outer matrix dimensions determine the size of the resulting
#         matrix, i.e. the answer is a 3 x 3 matrix.
#
#     Also note that ![](img23.gif). Usually, matrix multiplication is not
#     commutative, as in this case. However, there are situations where
#     two matrices are commutative, e.g.,
#
#     ![](img24.gif)
#
#     In this case, **XY = YX**:
#
#     ![](img25.gif)
#
#     Also note that if two matrices are inverse of each other, they are
#     commutative as well.
#
# 8.  **AA** *i.e. ![](img26.gif) times ![](img27.gif)*
#
#     ![](img28.gif)
#
#     Here, a 2 x 3 matrix is multiplied to a 2 x 3 matrix. Looking at the
#     matrix, you can see that there is nothing to be multiplied by -4.
#     Consider the subscripts:
#
#     ![](img29.gif)
#
#     Note that the inner matrix dimensions (pointed by arrows) do not
#     agree. Therefore, the answer is undefined.
#
# \
#
# ------------------------------------------------------------------------
#
# *John M. Stockie\
# Fri Sep 8 14:43:09 PDT 1995*
