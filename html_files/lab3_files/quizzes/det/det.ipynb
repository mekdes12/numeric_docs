# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8888/notebooks/det/det.ipynb#Solution-to-Determinant" data-toc-modified-id="Solution-to-Determinant-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Solution to Determinant</a></span></li></ul></div>

# %% [markdown]
# Solution to Determinant
# ============
#
# ****
#
# ****
#
# 1.  Given
#
#     $$A = \begin{bmatrix}
#        3 & -2 & 1\\
#        1 & 5 & -1 \\
#        -1 & 0 & 0
#        \end{bmatrix}$$
#
#
# The third row has the most zero entries, so the matrix will be
# multiplied about this row to find the determinant. The reason for
# choosing this row will become clear below.\
#
# To find the determinant, you need to first find the components that make up the determinant of the matrix.
#
# For each element $a_{ij}$  in the chosen row i of a $n\times n$ matrix, $a_{ij}$ is multiplied by the determinant of the matrix without the row i and the column j i.e. an  $(n-1)\times (n-1)$  matrix.\
#
# In this case, the first element is -1, and the $(n-1)\times (n-1)$ matrix is the original matrix without row 3 and column 1:
#
#    $$B = \begin{bmatrix}
#        3 & -2 & 1\\
#        1 & 5 & -1 \\
#        -1 & 0 & 0
#        \end{bmatrix} \rightarrow det \begin{bmatrix}
#         -2 & 1\\
#        5 & -1
#        \end{bmatrix}$$
#
#
# This is the first component for calculating det(A).
#
# The other components are derived the same way:
#
#    $$B = \begin{bmatrix}
#        3 & -2 & 1\\
#        1 & 5 & -1 \\
#        -1 & 0 & 0
#        \end{bmatrix} \rightarrow det \begin{bmatrix}
#         3 & 1\\
#        1 & -1
#        \end{bmatrix}$$
#
#    $$B = \begin{bmatrix}
#        3 & -2 & 1\\
#        1 & 5 & -1 \\
#        -1 & 0 & 0
#        \end{bmatrix} \rightarrow det \begin{bmatrix}
#         3 & -2\\
#        1 & 5
#        \end{bmatrix}$$
#
#
# Before adding the components together to find the determinant, there
# is one extra factor that is necessary.
#
# Each component has to be multiplied by the number $(-1)^{i+j}$, where i and j are the row
# and column, respectively, that contain the element from the chosen row.\
#
# So when everything is put together:
#
# $$
#    \begin{align}
#  \det(A) & =(-1^{3+1})(-1)det \begin{bmatrix}
#        -2 & 1\\
#         5 & -1
#        \end{bmatrix} + (-1^{3+2})0\det\begin{bmatrix}
#        3 & 1\\
#         1 & -1
#        \end{bmatrix} + (-1^{3+3})0\det\begin{bmatrix}
#        3 & -2\\
#         1 & 5
#        \end{bmatrix} \\
#       & = -1\left\{(-2)(-1) - (1)(5)\right\} \quad \quad
#       - 0         \quad \quad \quad \quad \quad \quad \quad \quad + 0\\
#       & = 3
#     \end{align}
# $$
#
#  So **A** has an inverse.
#
#  Note that since two of the elements in row three are 0, in
#  calculating the determinant, two of the components can easily be
#  removed, because they are 0.
#
# 2.  Given
#
#    $$ B = \begin{bmatrix}
#       4& -6 & 1\\
#        1& -3 & 1\\
#        2 & 0 & -1
#        \end{bmatrix}$$
#
#     The third row should be chosen since it has the most zero entries.
#     In the same way as the previous question, the various components are
#     derived, so:
#
#
#
#    $$ \begin{align}
#    \det(B) & =(-1^{3+1})2 \det \begin{bmatrix}
#        -6 & 1\\
#         -3 & 1
#        \end{bmatrix} + (-1^{3+2})0\det\begin{bmatrix}
#        4 & 1\\
#         1 & 1
#        \end{bmatrix} + (-1^{3+3})(-1)\det\begin{bmatrix}
#        4 & -6\\
#         1 & -3
#        \end{bmatrix} \\
#        & = 2\left\{(-6)(1) - (1)(-3)\right\}  \quad -  0 \quad \quad \quad \quad \quad \quad \quad + (-1)\left\{(4)(-3)-(-6)(1)\right\}\\
#        & = -6 \qquad \qquad  \qquad \qquad - 0 \qquad \qquad \qquad \quad + 6\\
#        & = 0
#       \end{align}
#    $$
#
#
#     **B** is singular, i.e. it does not have an inverse.
#
# 3.  Given
#
# $$ C = \begin{bmatrix}
#       4& -2 & -7 & 6\\
#        -3 & 0 & 1 & 0\\
#        -1 & -1 & 5 & -1\\
#        0 & 1 & -5 & 3
#        \end{bmatrix}$$
#
#
#     With Python,\
#
#     Python:1**&gt;**  C = np.matrix('4 -2 -7 6; -3 0 1 0;-1 -1 5 -1; 0 1 -5 3')
#     python:2**&gt;** np.linalg.det(C)\
#     \
#
#     you should get
#
#    $$ \det(C)= -82$$
#
#     **C** is non-singular, since
#     its determinant is not zero. So it has an inverse.
#
# \
#
# ------------------------------------------------------------------------
#
# *John M. Stockie\
# Fri Sep 8 14:05:45 PDT 2017*
